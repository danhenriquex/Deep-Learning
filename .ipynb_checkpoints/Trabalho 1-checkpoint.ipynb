# %%
import imageio
import numpy as np
from PIL import Image, ImageOps
import matplotlib.pyplot as plt

# %%
#img = imageio.v3.imread('./leclerc.jpg')

# %% [markdown]
# ## Funções para plotar

# %%
# Plota 1 imagem

def plot_image(img: np.array):
    plt.figure(figsize=(6, 6))
    plt.imshow(img, cmap='gray');
    
# Plota as 2 imagens
    
def plot_two_images(img1: np.array, img2: np.array):
    _, ax = plt.subplots(1, 2, figsize=(12, 6))
    ax[0].imshow(img1, cmap='gray')
    ax[1].imshow(img2, cmap='gray');

# %% [markdown]
# ## Carrega a imagem e aplica a cor cinza

# %%
img = Image.open('messi.webp')
img = ImageOps.grayscale(img)
img = img.resize(size=(224, 224))
plot_image(img=img)

# %% [markdown]
# ## Calcula quantos filtros você pode aplicar na imagem

# %%
def calculate_target_size(img_size: int, kernel_size: int) -> int:
    num_pixels = 0
    
    for i in range(img_size):
        added = i + kernel_size
  
        if added <= img_size:
            num_pixels += 1
            
    return num_pixels

# %%
plot_image(img)

# %% [markdown]
# ## Filtros

# %%
sharpen = np.array([
    [0, -1, 0],
    [-1, 5, -1],
    [0, -1, 0]
])

blur = np.array([
    [0.0625, 0.125, 0.0625],
    [0.125,  0.25,  0.125],
    [0.0625, 0.125, 0.0625]
])

#blur = np.array([1])

outline = np.array([
    [-1, -1, -1],
    [-1,  8, -1],
    [-1, -1, -1]
])

# %% [markdown]
# ## Função para aplicar a convolução

# %%
def convolve(img: np.array, kernel: np.array) -> np.array:

    tgt_size = calculate_target_size(
        img_size=img.shape[0],
        kernel_size=kernel.shape[0]
    )
    
    print(tgt_size)

    k = kernel.shape[0]
    l = kernel.shape[1]
    
    active = False
    
    if k == l:
        active = True
    
    convolved_img = np.zeros(shape=(tgt_size, tgt_size))
    
    print(k)
    
    for i in range(tgt_size):
    
        for j in range(tgt_size):
            
            mat = img[i:i+k, j:j+l]
            
            if active:
                convolved_img[i, j] = np.sum(np.multiply(mat, kernel))
            else:
                if not mat.shape[1] == k:
                    convolved_img[i, j] = np.sum(np.multiply(mat, kernel))
                else:
                    pass
            
               
        
            
            
    return convolved_img

# %%
img_sharpened = convolve(img=np.array(img), kernel=blur)
img_sharpened
# Out:
# 222
# 3
# array([[66.6875, 64.6875, 75.8125, ..., 85.25  , 54.4375, 27.375 ],
#        [59.75  , 51.875 , 65.375 , ..., 81.375 , 50.375 , 23.75  ],
#        [41.9375, 33.625 , 51.6875, ..., 74.625 , 46.625 , 19.9375],
#        ...,
#        [50.4375, 54.5   , 49.0625, ..., 50.0625, 47.625 , 44.875 ],
#        [46.6875, 45.    , 44.875 , ..., 49.375 , 47.    , 45.75  ],
#        [48.375 , 47.0625, 48.6875, ..., 44.5625, 43.    , 42.125 ]])

# %%
plot_two_images(
    img1=img, 
    img2=img_sharpened
)

# %% [markdown]
# ## Solving padding problem

# %%
def get_padding_width_per_side(kernel_size: int) -> int:

    return kernel_size // 2

# %%
def add_padding_to_image(img: np.array, padding_width: int) -> np.array:
    
    img_with_padding = np.zeros(shape=(
        img.shape[0] + padding_width * 2,  
        img.shape[1] + padding_width * 2
    ))
    
    img_with_padding[padding_width:-padding_width, padding_width:-padding_width] = img
    
    return img_with_padding

# %%
pad_3x3 = get_padding_width_per_side(kernel_size=5)

# %%
img_with_padding_3x3 = add_padding_to_image(
    img=np.array(img), 
    padding_width=pad_3x3
)

print(img_with_padding_3x3.shape)
plot_image(img_with_padding_3x3)
# Out:
# (228, 228)

# %%
img_padded_3x3_sharpened = convolve(img=img_with_padding_3x3, kernel=sharpen)
print(img_padded_3x3_sharpened.shape)

plot_two_images(
    img1=img, 
    img2=img_padded_3x3_sharpened
)
# Out:
# 226
# 3
# (226, 226)

# %%
calculate_target_size(img_size=6, kernel_size=5)
# Out:
# 2
